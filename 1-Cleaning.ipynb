# %%
import numpy as np
import pandas as pd

import scipy.stats as sts
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Загрузка датасета №1 и его предобработка

# %%
df = pd.read_excel('datasets/coronavirus_Mar31.xlsx')
df.set_index("EVENT_ID_CNTY", inplace = True)
df['EVENT_DATE'] = pd.to_datetime(df['EVENT_DATE'])
df.head()
# Out:
#               EVENT_DATE  YEAR  TIME_PRECISION           DISORDER_TYPE  \
# EVENT_ID_CNTY
# XKX325        2020-03-13  2020               1  Strategic developments
# XKX326        2020-03-19  2020               1          Demonstrations
# XKX327        2020-03-20  2020               1          Demonstrations
# XKX328        2020-03-21  2020               1          Demonstrations
# XKX329        2020-03-21  2020               1          Demonstrations
#
#                            EVENT_TYPE            SUB_EVENT_TYPE  \
# EVENT_ID_CNTY
# XKX325         Strategic developments  Change to group/activity
# XKX326                       Protests          Peaceful protest
# XKX327                       Protests          Peaceful protest
# XKX328                       Protests          Peaceful protest
# XKX329                       Protests          Peaceful protest
#
#                                      ACTOR1 ASSOC_ACTOR_1  INTER1 ACTOR2  ...  \
# EVENT_ID_CNTY                                                             ...
# XKX325         Government of Kosovo (2020-)           NaN       1    NaN  ...
# XKX326                  Protesters (Kosovo)           NaN       6    NaN  ...
# XKX327                  Protesters (Kosovo)           NaN       6    NaN  ...
# XKX328                  Protesters (Kosovo)           NaN       6    NaN  ...
# XKX329                  Protesters (Kosovo)           NaN       6    NaN  ...
#
#                LOCATION  LATITUDE  LONGITUDE GEO_PRECISION             SOURCE  \
# EVENT_ID_CNTY
# XKX325         Pristina    42.667     21.172             3  Prishtina Insight
# XKX326         Pristina    42.667     21.172             1             RFE/RL
# XKX327         Pristina    42.667     21.172             1      Kosovo Online
# XKX328         Pristina    42.667     21.172             1            Sinjali
# XKX329             Peja    42.659     20.288             1            Sinjali
#
#                 SOURCE_SCALE  \
# EVENT_ID_CNTY
# XKX325              National
# XKX326         International
# XKX327              National
# XKX328              National
# XKX329              National
#
#                                                            NOTES FATALITIES  \
# EVENT_ID_CNTY
# XKX325         On 13 March 2020, the government of Kosovo ena...          0
# XKX326         On 19 March 2020, residents of Pristina, Kosov...          0
# XKX327         On 20 March 2020, residents of Pristina, Kosov...          0
# XKX328         On 21 March 2020, citizens took to their balco...          0
# XKX329         On 21 March 2020, citizens took to their balco...          0
#
#                                TAGS   TIMESTAMP
# EVENT_ID_CNTY
# XKX325                          NaN  1585075531
# XKX326         crowd size=no report  1585673085
# XKX327         crowd size=no report  1585673085
# XKX328         crowd size=no report  1585673076
# XKX329         crowd size=no report  1585673076
#
# [5 rows x 30 columns]

# %% [markdown]
# Датасет содержит наблюдения о беспорядках, столкновениях и иных конфликтах, непросредственно связанных с эпидемией COVID-19.
# ## Предобработка 1

# %%
df.value_counts(subset = ["DISORDER_TYPE", "EVENT_TYPE", "SUB_EVENT_TYPE"]) #Посмотрим на типы событий
# Out:
# DISORDER_TYPE                       EVENT_TYPE                  SUB_EVENT_TYPE
# Demonstrations                      Protests                    Peaceful protest                      56930
#                                     Riots                       Violent demonstration                  2658
#                                     Protests                    Protest with intervention              2046
# Political violence                  Riots                       Mob violence                           1529
# Strategic developments              Strategic developments      Change to group/activity                882
# Political violence                  Violence against civilians  Attack                                  851
# Strategic developments              Strategic developments      Other                                   254
#                                                                 Looting/property destruction            176
#                                                                 Arrests                                 112
# Political violence                  Battles                     Armed clash                             106
#                                     Violence against civilians  Abduction/forced disappearance           54
# Political violence; Demonstrations  Protests                    Excessive force against protesters       51
# Political violence                  Explosions/Remote violence  Remote explosive/landmine/IED            19
#                                     Violence against civilians  Sexual violence                          14
# Strategic developments              Strategic developments      Agreement                                12
#                                                                 Disrupted weapons use                    12
# Political violence                  Explosions/Remote violence  Grenade                                   6
#                                                                 Shelling/artillery/missile attack         2
#                                                                 Air/drone strike                          2
# dtype: int64

# %% [markdown]
# Видим, что подавляющее большинство событий - это мирные протесты. Рассмотрим данные по локациям и действующим лицам.

# %%
df[['COUNTRY', 'ADMIN1', 'ADMIN2', 'ADMIN3', 'LOCATION']].nunique()
# Out:
# COUNTRY       220
# ADMIN1       2022
# ADMIN2       7112
# ADMIN3       3669
# LOCATION    13999
# dtype: int64

# %%
df[['ACTOR1', 'ASSOC_ACTOR_1', 'ACTOR2', 'ASSOC_ACTOR_2']].nunique()
# Out:
# ACTOR1            946
# ASSOC_ACTOR_1    6639
# ACTOR2            611
# ASSOC_ACTOR_2    1037
# dtype: int64

# %%
df[['DISORDER_TYPE', 'EVENT_TYPE', 'SUB_EVENT_TYPE']].nunique()
# Out:
# DISORDER_TYPE      4
# EVENT_TYPE         6
# SUB_EVENT_TYPE    19
# dtype: int64

# %% [markdown]
# Становится ясно, что никакого OneHotEncoding по геоданным и акторам не будет, да вообще эти данные кроме визуализаций и присоединения других показателей не очень то нужны.
# А вот типы событий имеет смысл OneHot'нуть.

# %%
df.value_counts(subset = ["REGION"]) #Посмотрим на распределение наблюдений по регионам
# Out:
# REGION
# Europe                       25071
# North America                10796
# South America                 8482
# South Asia                    7807
# Middle East                   3121
# East Asia                     2922
# Northern Africa               1574
# Southeast Asia                1293
# Central America               1062
# Caucasus and Central Asia      696
# Oceania                        637
# Eastern Africa                 624
# Caribbean                      584
# Southern Africa                440
# Western Africa                 413
# Middle Africa                  194
# dtype: int64

# %% [markdown]
# Видим, что больше половины наблюдений приходится на Европу и Северную Америку. Сравним Китай и США

# %%
print(df[df["COUNTRY"] == "China"].value_counts(subset = ["COUNTRY"]))
print(df[df["COUNTRY"] == "United States"].value_counts(subset = ["COUNTRY"]))
# Out:
# COUNTRY
# China      629
# dtype: int64
# COUNTRY
# United States    7966
# dtype: int64

# %% [markdown]
# Есть некоторые подозрения по поводу количества наблюдений в полутрамиллиардном Китае. Посмотрим на источники.

# %%
print("КИТАЙ: \n", df[df["COUNTRY"] == "China"].value_counts(subset = ["SOURCE_SCALE", "SOURCE"]), "\n")
print("США: \n", df[df["COUNTRY"] == "United States"].value_counts(subset = ["SOURCE_SCALE", "SOURCE"]))
# Out:
# КИТАЙ:
#  SOURCE_SCALE            SOURCE
# Subnational             Inmediahk.net                       79
#                         HK01                                65
#                         Wen Wei Po                          55
# International           Radio Free Asia                     55
# Other                   CLB (China)                         40
#                                                             ..
# Other-Subnational       China Aid; Inmediahk.net             1
#                         Apple Daily Hong Kong; China Aid     1
# Other-New media         Twitter; CLB (China)                 1
# National-International  Deutsche Welle; HK01                 1
# Other-National          Weiquanwang; RTHK                    1
# Length: 134, dtype: int64
#
# США:
#  SOURCE_SCALE          SOURCE
# New media             Twitter                                                                     127
# Other                 California Nurses Association                                                44
# Subnational           KRQE                                                                         35
#                       New York Post                                                                34
# Other                 Liberation News                                                              32
#                                                                                                  ...
# Subnational           13WHAM ABC; News 8 (Rochester)                                                1
# Other-Subnational     10 Tampa Bay; Count Love                                                      1
# Subnational           1420/102.7 KTOE                                                               1
#                       16WAPT                                                                        1
# Subnational-National  Winona Daily News; Beaver Dam Daily Citizen; Kenosha News; Journal Times      1
# Length: 4073, dtype: int64

# %% [markdown]
# Ожидаемо, данные для США берут из открытых внутренних источников, данные для Китая - из внешних, до которых доходит гораздо меньше событий.

# %%
df.value_counts(subset = ['TIMESTAMP'])
# Out:
# TIMESTAMP
# 1643149412    361
# 1677617817    303
# 1631575313    275
# 1680633575    263
# 1642536651    254
#              ...
# 1618498097      1
# 1618498094      1
# 1618498091      1
# 1618498090      1
# 1618499525      1
# Length: 9665, dtype: int64

# %% [markdown]
# Не очень то нужные значения, их даже как идентификатор события не выйдет использовать.

# %%
df["TAGS"].value_counts()
# Out:
# crowd size=no report                  36035
# crowd size=dozens                      1711
# crowd size=hundreds                    1455
# crowd size=around 100                  1013
# crowd size=around 50                    771
#                                       ...
# crowd size=around 2,100                   1
# crowd size=around 4,700                   1
# crowd size=around 1,412                   1
# crowd size=hundreds-more than 1000        1
# crowd size=unkown                         1
# Name: TAGS, Length: 3128, dtype: int64

# %% [markdown]
# Интерпретировать теги очень сложно, поэтому тоже отброшу.

# %%
df["ASSOC_ACTOR_1"].value_counts()
# Out:
# Labor Group (Italy)                                                                                      1036
# Students (United States)                                                                                  836
# Labor Group (Spain)                                                                                       831
# Labor Group (United States)                                                                               777
# Labor Group (India)                                                                                       776
#                                                                                                          ...
# Students (India); AISA: All India Students Association; SFI: Students Federation of India                   1
# NSUI: National Students Union of India; JKNC: Jammu and Kashmir National Conference; Students (India)       1
# Government of Pakistan (2018-2022); SP: Samajwadi Party                                                     1
# Farmers (India); KMSC: Farm Labourer Struggle Committee                                                     1
# Women (Yemen)                                                                                               1
# Name: ASSOC_ACTOR_1, Length: 6639, dtype: int64

# %% [markdown]
# Видим очевидную проблему - к "неорганизованным" объединениям присоединены названия стран, да еще и другие участники. Разделю их, чтобы можно было оценивать событие по участникам.

# %%
df['ACTOR1_TYPES'] = df["ASSOC_ACTOR_1"].fillna(df["ACTOR1"])
def process_string(row):
    new_string = row['ACTOR1_TYPES'].replace(' (' + row['COUNTRY'] + ')', '')
    return [new_string]
df['ACTOR1_TYPES'] = df.apply(lambda row: pd.Series(process_string(row)), axis=1)

# %% [markdown]
# А теперь сделаем признак "неорганизованность" - если событие не организовано формальным объединением, то признак равен 1, и наоборот.

# %%
df_actorcheck = df["ACTOR1_TYPES"].str.split(",", expand = True)
#Ниже список акторов, не являющихся организациями
my_list = ["Protesters", "Labor Group", "Health Workers", "Students", "Rioters", "Teachers", "Farmers", "Women", "Prisoners", "Taxi/Bus Drivers", "Lawyers", "Taxi Drivers", "No Vax", "Muslim Group", "Fishers", "Journalists", "Street Traders", "Orthodox Christian Group", "Protestant Christian Group", "Haredi Jewish Group", "Judges", "Refugees/IDPs", None]
def check_list(row):
    return int(all(elem in my_list for elem in row))

df['UNORGANIZED'] = df_actorcheck.apply(lambda row: check_list(row), axis=1)
df["UNORGANIZED"].value_counts()
# Out:
# 1    43124
# 0    22592
# Name: UNORGANIZED, dtype: int64

# %% [markdown]
# Примерно две трети событий оказались неорганизованными, это не очень хорошо - у нас дисбаланс классов.

# %%
df
# Out:
#               EVENT_DATE  YEAR  TIME_PRECISION           DISORDER_TYPE  \
# EVENT_ID_CNTY
# XKX325        2020-03-13  2020               1  Strategic developments
# XKX326        2020-03-19  2020               1          Demonstrations
# XKX327        2020-03-20  2020               1          Demonstrations
# XKX328        2020-03-21  2020               1          Demonstrations
# XKX329        2020-03-21  2020               1          Demonstrations
# ...                  ...   ...             ...                     ...
# ZAM1292       2020-04-12  2020               1      Political violence
# ZAM1300       2020-07-24  2020               1      Political violence
# ZAM1315       2020-09-26  2020               1      Political violence
# ZAM1323       2020-10-08  2020               2      Political violence
# ZAM1346       2021-03-01  2021               1      Political violence
#
#                                EVENT_TYPE            SUB_EVENT_TYPE  \
# EVENT_ID_CNTY
# XKX325             Strategic developments  Change to group/activity
# XKX326                           Protests          Peaceful protest
# XKX327                           Protests          Peaceful protest
# XKX328                           Protests          Peaceful protest
# XKX329                           Protests          Peaceful protest
# ...                                   ...                       ...
# ZAM1292        Violence against civilians                    Attack
# ZAM1300        Violence against civilians                    Attack
# ZAM1315        Violence against civilians                    Attack
# ZAM1323                             Riots              Mob violence
# ZAM1346                             Riots              Mob violence
#
#                                             ACTOR1 ASSOC_ACTOR_1  INTER1  \
# EVENT_ID_CNTY
# XKX325                Government of Kosovo (2020-)           NaN       1
# XKX326                         Protesters (Kosovo)           NaN       6
# XKX327                         Protesters (Kosovo)           NaN       6
# XKX328                         Protesters (Kosovo)           NaN       6
# XKX329                         Protesters (Kosovo)           NaN       6
# ...                                            ...           ...     ...
# ZAM1292        Police Forces of Zambia (2011-2021)           NaN       1
# ZAM1300        Police Forces of Zambia (2011-2021)           NaN       1
# ZAM1315        Police Forces of Zambia (2011-2021)           NaN       1
# ZAM1323                           Rioters (Zambia)           NaN       5
# ZAM1346                           Rioters (Zambia)           NaN       5
#
#                                             ACTOR2  ... LONGITUDE  \
# EVENT_ID_CNTY                                       ...
# XKX325                                         NaN  ...    21.172
# XKX326                                         NaN  ...    21.172
# XKX327                                         NaN  ...    21.172
# XKX328                                         NaN  ...    21.172
# XKX329                                         NaN  ...    20.288
# ...                                            ...  ...       ...
# ZAM1292                         Civilians (Zambia)  ...    29.497
# ZAM1300                         Civilians (Zambia)  ...    31.325
# ZAM1315                         Civilians (Zambia)  ...    28.283
# ZAM1323        Police Forces of Zambia (2011-2021)  ...    28.283
# ZAM1346                         Civilians (Zambia)  ...    23.117
#
#                GEO_PRECISION                           SOURCE   SOURCE_SCALE  \
# EVENT_ID_CNTY
# XKX325                     3                Prishtina Insight       National
# XKX326                     1                           RFE/RL  International
# XKX327                     1                    Kosovo Online       National
# XKX328                     1                          Sinjali       National
# XKX329                     1                          Sinjali       National
# ...                      ...                              ...            ...
# ZAM1292                    1                  Zambia Watchdog       National
# ZAM1300                    1                  Zambia Watchdog       National
# ZAM1315                    1  Mwebantu; Daily Nation (Zambia)       National
# ZAM1323                    1                     Lusaka Times    Subnational
# ZAM1346                    1                     Lusaka Times       National
#
#                                                            NOTES FATALITIES  \
# EVENT_ID_CNTY
# XKX325         On 13 March 2020, the government of Kosovo ena...          0
# XKX326         On 19 March 2020, residents of Pristina, Kosov...          0
# XKX327         On 20 March 2020, residents of Pristina, Kosov...          0
# XKX328         On 21 March 2020, citizens took to their balco...          0
# XKX329         On 21 March 2020, citizens took to their balco...          0
# ...                                                          ...        ...
# ZAM1292        On 12 April 2020, Zambian police attacked peop...          0
# ZAM1300        On 24 July 2020, a man was hit and injured by ...          0
# ZAM1315        On 26 September 2020, a teenage boy was shot a...          1
# ZAM1323        Around 8 October 2020 (as reported), a mob att...          1
# ZAM1346        On 1 March 2021, health workers were attacked ...          0
#
#                                TAGS   TIMESTAMP  \
# EVENT_ID_CNTY
# XKX325                          NaN  1585075531
# XKX326         crowd size=no report  1585673085
# XKX327         crowd size=no report  1585673085
# XKX328         crowd size=no report  1585673076
# XKX329         crowd size=no report  1585673076
# ...                             ...         ...
# ZAM1292                         NaN  1631575315
# ZAM1300                         NaN  1631575315
# ZAM1315                         NaN  1631575311
# ZAM1323        crowd size=no report  1631575314
# ZAM1346        crowd size=no report  1615246425
#
#                                       ACTOR1_TYPES UNORGANIZED
# EVENT_ID_CNTY
# XKX325                Government of Kosovo (2020-)           0
# XKX326                                  Protesters           1
# XKX327                                  Protesters           1
# XKX328                                  Protesters           1
# XKX329                                  Protesters           1
# ...                                            ...         ...
# ZAM1292        Police Forces of Zambia (2011-2021)           0
# ZAM1300        Police Forces of Zambia (2011-2021)           0
# ZAM1315        Police Forces of Zambia (2011-2021)           0
# ZAM1323                                    Rioters           1
# ZAM1346                                    Rioters           1
#
# [65716 rows x 32 columns]

# %% [markdown]
# ## Предобработка 2
# Теперь подгружаем второй датасет, в нем ежедневная информация о заболеваемости по странам (и куча лишнего мусора).

# %%
df_cov = pd.read_csv("datasets/owid-covid-data.csv")
df_cov['date'] = pd.to_datetime(df_cov['date'])
df_cov
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 166321      ZWE    Africa     Zimbabwe 2022-03-01     236871.0      491.0
# 166322      ZWE    Africa     Zimbabwe 2022-03-02     237503.0      632.0
# 166323      ZWE    Africa     Zimbabwe 2022-03-03     237503.0        0.0
# 166324      ZWE    Africa     Zimbabwe 2022-03-04     238739.0     1236.0
# 166325      ZWE    Africa     Zimbabwe 2022-03-05     239019.0      280.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 166321             413.000        5395.0         0.0                1.000
# 166322             416.286        5396.0         1.0                1.143
# 166323             362.286        5396.0         0.0                0.857
# 166324             467.429        5397.0         1.0                0.714
# 166325             459.429        5397.0         0.0                0.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 166321  ...             1.6          30.7                  36.791
# 166322  ...             1.6          30.7                  36.791
# 166323  ...             1.6          30.7                  36.791
# 166324  ...             1.6          30.7                  36.791
# 166325  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 166321                         1.7            61.49                    0.571
# 166322                         1.7            61.49                    0.571
# 166323                         1.7            61.49                    0.571
# 166324                         1.7            61.49                    0.571
# 166325                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 166321                                   NaN                          NaN
# 166322                                   NaN                          NaN
# 166323                                   NaN                          NaN
# 166324                                   NaN                          NaN
# 166325                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 166321               NaN                                      NaN
# 166322               NaN                                      NaN
# 166323               NaN                                      NaN
# 166324               NaN                                      NaN
# 166325               NaN                                      NaN
#
# [166326 rows x 67 columns]

# %% [markdown]
# Во - первых, в датасетах наверняка есть несовпадения по странам. Посмотрим на них

# %%
unknown = set(df["COUNTRY"].tolist()) - set(df_cov["location"].tolist())
print(unknown)
# Out:
# {'Czech Republic', 'Bailiwick of Guernsey', 'eSwatini', 'Ivory Coast', 'Bailiwick of Jersey', 'North Korea', 'Saint-Barthelemy', 'Northern Mariana Islands', 'American Samoa', 'Guadeloupe', 'French Guiana', 'Puerto Rico', 'Caribbean Netherlands', 'East Timor', 'Saint Helena, Ascension and Tristan da Cunha', 'Saint-Martin', 'Sint Maarten', 'Guam', 'Martinique', 'Reunion', 'Virgin Islands, U.S.', 'Republic of Congo'}

# %%
droplist = list(set(df_cov["location"].tolist()) - set(df["COUNTRY"].tolist()))
set(df_cov["location"].tolist()) - set(df["COUNTRY"].tolist())#Это несовпавшие страны из датасета по заболеваемости
# Out:
# {'Africa',
#  'Asia',
#  'Bonaire Sint Eustatius and Saba',
#  'British Virgin Islands',
#  'Comoros',
#  'Congo',
#  "Cote d'Ivoire",
#  'Czechia',
#  'Eswatini',
#  'Europe',
#  'European Union',
#  'Faeroe Islands',
#  'Greenland',
#  'Guernsey',
#  'High income',
#  'Hong Kong',
#  'International',
#  'Jersey',
#  'Kiribati',
#  'Low income',
#  'Lower middle income',
#  'Macao',
#  'Marshall Islands',
#  'Micronesia (country)',
#  'Niue',
#  'North America',
#  'Northern Cyprus',
#  'Oceania',
#  'Palau',
#  'Pitcairn',
#  'Saint Helena',
#  'Sao Tome and Principe',
#  'Sint Maarten (Dutch part)',
#  'South America',
#  'Timor',
#  'Tokelau',
#  'Tuvalu',
#  'Upper middle income',
#  'Vatican',
#  'World'}

# %% [markdown]
# Несостыкованных стран много, и наверняка когда мы начнем добавлять дополнительные данные, с ними возникнет такая же проблема, поэтому применим грязный трюк:

# %%
df[["COUNTRY","ISO"]][df["COUNTRY"].isin(unknown)].groupby("COUNTRY").count().sort_values(by = "ISO", ascending = False)
# Out:
#                                               ISO
# COUNTRY
# Czech Republic                                246
# Guadeloupe                                    241
# Martinique                                     95
# Reunion                                        69
# North Korea                                    55
# French Guiana                                  49
# Saint-Martin                                   29
# Ivory Coast                                    23
# Puerto Rico                                    20
# eSwatini                                       14
# Guam                                           10
# East Timor                                      7
# Republic of Congo                               5
# Sint Maarten                                    5
# American Samoa                                  4
# Bailiwick of Jersey                             3
# Bailiwick of Guernsey                           2
# Caribbean Netherlands                           2
# Saint Helena, Ascension and Tristan da Cunha    2
# Northern Mariana Islands                        1
# Saint-Barthelemy                                1
# Virgin Islands, U.S.                            1

# %% [markdown]
# Выкинем все страны кроме первых (по остальным мало наблюдений), причем у нас нет данных по заболеваемости в Guadeloupe, Martinique, Reunion и тем более в North Korea, так что оставляем только Чехию.

# %%
df_cov["location"].replace(to_replace = "Czechia", value = "Czech Republic", inplace = True)
df_cov = df_cov.drop(df_cov[df_cov["location"].isin(droplist)].index)
df_cov
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 166321      ZWE    Africa     Zimbabwe 2022-03-01     236871.0      491.0
# 166322      ZWE    Africa     Zimbabwe 2022-03-02     237503.0      632.0
# 166323      ZWE    Africa     Zimbabwe 2022-03-03     237503.0        0.0
# 166324      ZWE    Africa     Zimbabwe 2022-03-04     238739.0     1236.0
# 166325      ZWE    Africa     Zimbabwe 2022-03-05     239019.0      280.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 166321             413.000        5395.0         0.0                1.000
# 166322             416.286        5396.0         1.0                1.143
# 166323             362.286        5396.0         0.0                0.857
# 166324             467.429        5397.0         1.0                0.714
# 166325             459.429        5397.0         0.0                0.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 166321  ...             1.6          30.7                  36.791
# 166322  ...             1.6          30.7                  36.791
# 166323  ...             1.6          30.7                  36.791
# 166324  ...             1.6          30.7                  36.791
# 166325  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 166321                         1.7            61.49                    0.571
# 166322                         1.7            61.49                    0.571
# 166323                         1.7            61.49                    0.571
# 166324                         1.7            61.49                    0.571
# 166325                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 166321                                   NaN                          NaN
# 166322                                   NaN                          NaN
# 166323                                   NaN                          NaN
# 166324                                   NaN                          NaN
# 166325                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 166321               NaN                                      NaN
# 166322               NaN                                      NaN
# 166323               NaN                                      NaN
# 166324               NaN                                      NaN
# 166325               NaN                                      NaN
#
# [143139 rows x 67 columns]

# %% [markdown]
# Соединим датасеты

# %%
#создание служебных колонок для присоединения
df_cov["LOCDATE"] = df_cov["location"] + df_cov["date"].astype("str")
df["LOCDATE"] = df["COUNTRY"] + df["EVENT_DATE"].astype("str")

# %%
df_data = pd.merge(df, df_cov, on = "LOCDATE", how = "left")

# %% [markdown]
# Сразу проверим, где не склеилось

# %%
df_data[df_data["location"].isna()]
# Out:
#       EVENT_DATE  YEAR  TIME_PRECISION           DISORDER_TYPE  \
# 0     2020-03-13  2020               1  Strategic developments
# 44    2022-05-25  2022               1          Demonstrations
# 45    2022-07-29  2022               1          Demonstrations
# 46    2022-10-21  2022               1          Demonstrations
# 83    2022-03-09  2022               2          Demonstrations
# ...          ...   ...             ...                     ...
# 65657 2020-04-08  2020               1      Political violence
# 65658 2020-04-08  2020               1      Political violence
# 65659 2020-04-08  2020               1      Political violence
# 65660 2020-04-09  2020               1  Strategic developments
# 65661 2020-04-09  2020               1  Strategic developments
#
#                        EVENT_TYPE            SUB_EVENT_TYPE  \
# 0          Strategic developments  Change to group/activity
# 44                       Protests          Peaceful protest
# 45                       Protests          Peaceful protest
# 46                       Protests          Peaceful protest
# 83                       Protests          Peaceful protest
# ...                           ...                       ...
# 65657  Violence against civilians                    Attack
# 65658  Violence against civilians                    Attack
# 65659  Violence against civilians                    Attack
# 65660      Strategic developments                     Other
# 65661      Strategic developments                     Other
#
#                                                   ACTOR1  \
# 0                           Government of Kosovo (2020-)
# 44                                   Protesters (Kosovo)
# 45                                   Protesters (Kosovo)
# 46                                   Protesters (Kosovo)
# 83                              Protesters (Afghanistan)
# ...                                                  ...
# 65657  Military Forces of Yemen (2016-) Supreme Polit...
# 65658  Military Forces of Yemen (2016-) Supreme Polit...
# 65659                           Operation Restoring Hope
# 65660  Military Forces of Yemen (2016-) Supreme Polit...
# 65661                           Operation Restoring Hope
#
#                                            ASSOC_ACTOR_1  INTER1  \
# 0                                                    NaN       1
# 44                               Health Workers (Kosovo)       6
# 45         Health Workers (Kosovo); Labor Group (Kosovo)       6
# 46                PSD: Social Democratic Party of Kosovo       6
# 83     Health Workers (Afghanistan); Labor Group (Afg...       6
# ...                                                  ...     ...
# 65657                                                NaN       1
# 65658                                                NaN       1
# 65659  Military Forces of Saudi Arabia (2015-) Border...       8
# 65660                                                NaN       1
# 65661                                                NaN       8
#
#                      ACTOR2  ... female_smokers  male_smokers  \
# 0                       NaN  ...            NaN           NaN
# 44                      NaN  ...            NaN           NaN
# 45                      NaN  ...            NaN           NaN
# 46                      NaN  ...            NaN           NaN
# 83                      NaN  ...            NaN           NaN
# ...                     ...  ...            ...           ...
# 65657  Civilians (Ethiopia)  ...            NaN           NaN
# 65658  Civilians (Ethiopia)  ...            NaN           NaN
# 65659  Civilians (Ethiopia)  ...            NaN           NaN
# 65660     Civilians (Yemen)  ...            NaN           NaN
# 65661                   NaN  ...            NaN           NaN
#
#        handwashing_facilities hospital_beds_per_thousand  life_expectancy  \
# 0                         NaN                        NaN              NaN
# 44                        NaN                        NaN              NaN
# 45                        NaN                        NaN              NaN
# 46                        NaN                        NaN              NaN
# 83                        NaN                        NaN              NaN
# ...                       ...                        ...              ...
# 65657                     NaN                        NaN              NaN
# 65658                     NaN                        NaN              NaN
# 65659                     NaN                        NaN              NaN
# 65660                     NaN                        NaN              NaN
# 65661                     NaN                        NaN              NaN
#
#       human_development_index excess_mortality_cumulative_absolute  \
# 0                         NaN                                  NaN
# 44                        NaN                                  NaN
# 45                        NaN                                  NaN
# 46                        NaN                                  NaN
# 83                        NaN                                  NaN
# ...                       ...                                  ...
# 65657                     NaN                                  NaN
# 65658                     NaN                                  NaN
# 65659                     NaN                                  NaN
# 65660                     NaN                                  NaN
# 65661                     NaN                                  NaN
#
#       excess_mortality_cumulative excess_mortality  \
# 0                             NaN              NaN
# 44                            NaN              NaN
# 45                            NaN              NaN
# 46                            NaN              NaN
# 83                            NaN              NaN
# ...                           ...              ...
# 65657                         NaN              NaN
# 65658                         NaN              NaN
# 65659                         NaN              NaN
# 65660                         NaN              NaN
# 65661                         NaN              NaN
#
#       excess_mortality_cumulative_per_million
# 0                                         NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 83                                        NaN
# ...                                       ...
# 65657                                     NaN
# 65658                                     NaN
# 65659                                     NaN
# 65660                                     NaN
# 65661                                     NaN
#
# [2993 rows x 100 columns]

# %% [markdown]
# Увы, с этими наблюдениями придется расстаться - на них просто нет данных по заболеваемости

# %%
df_data = df_data.drop(df_data[df_data["location"].isna()].index)
df_data
# Out:
#       EVENT_DATE  YEAR  TIME_PRECISION       DISORDER_TYPE  \
# 1     2020-03-19  2020               1      Demonstrations
# 2     2020-03-20  2020               1      Demonstrations
# 3     2020-03-21  2020               1      Demonstrations
# 4     2020-03-21  2020               1      Demonstrations
# 5     2020-03-21  2020               1      Demonstrations
# ...          ...   ...             ...                 ...
# 65711 2020-04-12  2020               1  Political violence
# 65712 2020-07-24  2020               1  Political violence
# 65713 2020-09-26  2020               1  Political violence
# 65714 2020-10-08  2020               2  Political violence
# 65715 2021-03-01  2021               1  Political violence
#
#                        EVENT_TYPE    SUB_EVENT_TYPE  \
# 1                        Protests  Peaceful protest
# 2                        Protests  Peaceful protest
# 3                        Protests  Peaceful protest
# 4                        Protests  Peaceful protest
# 5                        Protests  Peaceful protest
# ...                           ...               ...
# 65711  Violence against civilians            Attack
# 65712  Violence against civilians            Attack
# 65713  Violence against civilians            Attack
# 65714                       Riots      Mob violence
# 65715                       Riots      Mob violence
#
#                                     ACTOR1 ASSOC_ACTOR_1  INTER1  \
# 1                      Protesters (Kosovo)           NaN       6
# 2                      Protesters (Kosovo)           NaN       6
# 3                      Protesters (Kosovo)           NaN       6
# 4                      Protesters (Kosovo)           NaN       6
# 5                      Protesters (Kosovo)           NaN       6
# ...                                    ...           ...     ...
# 65711  Police Forces of Zambia (2011-2021)           NaN       1
# 65712  Police Forces of Zambia (2011-2021)           NaN       1
# 65713  Police Forces of Zambia (2011-2021)           NaN       1
# 65714                     Rioters (Zambia)           NaN       5
# 65715                     Rioters (Zambia)           NaN       5
#
#                                     ACTOR2  ... female_smokers  male_smokers  \
# 1                                      NaN  ...            NaN           NaN
# 2                                      NaN  ...            NaN           NaN
# 3                                      NaN  ...            NaN           NaN
# 4                                      NaN  ...            NaN           NaN
# 5                                      NaN  ...            NaN           NaN
# ...                                    ...  ...            ...           ...
# 65711                   Civilians (Zambia)  ...            3.1          24.7
# 65712                   Civilians (Zambia)  ...            3.1          24.7
# 65713                   Civilians (Zambia)  ...            3.1          24.7
# 65714  Police Forces of Zambia (2011-2021)  ...            3.1          24.7
# 65715                   Civilians (Zambia)  ...            3.1          24.7
#
#        handwashing_facilities hospital_beds_per_thousand  life_expectancy  \
# 1                         NaN                        NaN              NaN
# 2                         NaN                        NaN              NaN
# 3                         NaN                        NaN              NaN
# 4                         NaN                        NaN              NaN
# 5                         NaN                        NaN              NaN
# ...                       ...                        ...              ...
# 65711                  13.938                        2.0            63.89
# 65712                  13.938                        2.0            63.89
# 65713                  13.938                        2.0            63.89
# 65714                  13.938                        2.0            63.89
# 65715                  13.938                        2.0            63.89
#
#       human_development_index excess_mortality_cumulative_absolute  \
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3                         NaN                                  NaN
# 4                         NaN                                  NaN
# 5                         NaN                                  NaN
# ...                       ...                                  ...
# 65711                   0.584                                  NaN
# 65712                   0.584                                  NaN
# 65713                   0.584                                  NaN
# 65714                   0.584                                  NaN
# 65715                   0.584                                  NaN
#
#       excess_mortality_cumulative excess_mortality  \
# 1                             NaN              NaN
# 2                             NaN              NaN
# 3                             NaN              NaN
# 4                             NaN              NaN
# 5                             NaN              NaN
# ...                           ...              ...
# 65711                         NaN              NaN
# 65712                         NaN              NaN
# 65713                         NaN              NaN
# 65714                         NaN              NaN
# 65715                         NaN              NaN
#
#       excess_mortality_cumulative_per_million
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# ...                                       ...
# 65711                                     NaN
# 65712                                     NaN
# 65713                                     NaN
# 65714                                     NaN
# 65715                                     NaN
#
# [62723 rows x 100 columns]

# %% [markdown]
# # Чистка 1
# Удалю ненужные столбцы, которые не помогут при анализе. Для начала те, в которых наблюдений много, но они не нужны, а потом те, в которых данных мало.

# %%
useless = [
    'YEAR',
    'NOTES', #Текстовое описание новости
    'SOURCE', #Источник
    'TIME_PRECISION', #Точность определения времени события
    'TIMESTAMP', #Как оказалось, это время внесения наблюдения в таблицу
    'GEO_PRECISION', #Точность географической оценки
    'TAGS', #Плохо сделанные теги
    'ACTOR1', 
    'ASSOC_ACTOR_1', #Действующие лица
    'ACTOR2', 
    'ASSOC_ACTOR_2', 
    'CIVILIAN_TARGETING', #Было ли направленное именно на гражданские лица насилие
    'ADMIN1', 
    'ADMIN2',
    'ADMIN3', #Место действия
    'LOCATION',
    'INTERACTION',
    'ACTOR1_TYPES' #Служебная колонка из пункта выше
]

# %%
df_data = df_data.drop(useless, axis = 1)

# %%
limit = df_data.shape[0] * 0.05 #поставим порог в 5%, пока что
df_data = df_data.drop(df_data.columns[df_data.isna().sum() > limit], axis = 1)

# %% [markdown]
# Сохраним все события в табличку для визуализаций

# %%
df_data.to_excel("datasets/disorders.xlsx", encoding='utf-8')

# %% [markdown]
# Отдельно сохраним именно протесты (пригодится в будущем)

# %%
df_protests = df_data[df_data["DISORDER_TYPE"] == "Demonstrations"]
df_protests.to_excel("datasets/protests.xlsx", encoding='utf-8')

# %%
df_data
# Out:
#       EVENT_DATE       DISORDER_TYPE                  EVENT_TYPE  \
# 1     2020-03-19      Demonstrations                    Protests
# 2     2020-03-20      Demonstrations                    Protests
# 3     2020-03-21      Demonstrations                    Protests
# 4     2020-03-21      Demonstrations                    Protests
# 5     2020-03-21      Demonstrations                    Protests
# ...          ...                 ...                         ...
# 65711 2020-04-12  Political violence  Violence against civilians
# 65712 2020-07-24  Political violence  Violence against civilians
# 65713 2020-09-26  Political violence  Violence against civilians
# 65714 2020-10-08  Political violence                       Riots
# 65715 2021-03-01  Political violence                       Riots
#
#          SUB_EVENT_TYPE  INTER1  INTER2  ISO           REGION COUNTRY  \
# 1      Peaceful protest       6       0    0           Europe  Kosovo
# 2      Peaceful protest       6       0    0           Europe  Kosovo
# 3      Peaceful protest       6       0    0           Europe  Kosovo
# 4      Peaceful protest       6       0    0           Europe  Kosovo
# 5      Peaceful protest       6       0    0           Europe  Kosovo
# ...                 ...     ...     ...  ...              ...     ...
# 65711            Attack       1       7  894  Southern Africa  Zambia
# 65712            Attack       1       7  894  Southern Africa  Zambia
# 65713            Attack       1       7  894  Southern Africa  Zambia
# 65714      Mob violence       5       1  894  Southern Africa  Zambia
# 65715      Mob violence       5       7  894  Southern Africa  Zambia
#
#        LATITUDE  ...  median_age aged_65_older  aged_70_older  gdp_per_capita  \
# 1        42.667  ...         NaN           NaN            NaN        9795.834
# 2        42.667  ...         NaN           NaN            NaN        9795.834
# 3        42.667  ...         NaN           NaN            NaN        9795.834
# 4        42.659  ...         NaN           NaN            NaN        9795.834
# 5        42.638  ...         NaN           NaN            NaN        9795.834
# ...         ...  ...         ...           ...            ...             ...
# 65711   -13.700  ...        17.7          2.48          1.542        3689.251
# 65712   -14.243  ...        17.7          2.48          1.542        3689.251
# 65713   -15.417  ...        17.7          2.48          1.542        3689.251
# 65714   -15.417  ...        17.7          2.48          1.542        3689.251
# 65715   -13.550  ...        17.7          2.48          1.542        3689.251
#
#       cardiovasc_death_rate diabetes_prevalence female_smokers  \
# 1                       NaN                 NaN            NaN
# 2                       NaN                 NaN            NaN
# 3                       NaN                 NaN            NaN
# 4                       NaN                 NaN            NaN
# 5                       NaN                 NaN            NaN
# ...                     ...                 ...            ...
# 65711               234.499                3.94            3.1
# 65712               234.499                3.94            3.1
# 65713               234.499                3.94            3.1
# 65714               234.499                3.94            3.1
# 65715               234.499                3.94            3.1
#
#       hospital_beds_per_thousand life_expectancy  human_development_index
# 1                            NaN             NaN                      NaN
# 2                            NaN             NaN                      NaN
# 3                            NaN             NaN                      NaN
# 4                            NaN             NaN                      NaN
# 5                            NaN             NaN                      NaN
# ...                          ...             ...                      ...
# 65711                        2.0           63.89                    0.584
# 65712                        2.0           63.89                    0.584
# 65713                        2.0           63.89                    0.584
# 65714                        2.0           63.89                    0.584
# 65715                        2.0           63.89                    0.584
#
# [62723 rows x 45 columns]

# %%
df_data.isna().sum().sort_values(ascending=False)
# Out:
# female_smokers                     2801
# new_deaths_smoothed_per_million    2057
# new_deaths_smoothed                2057
# reproduction_rate                  1208
# new_deaths_per_million              960
# new_deaths                          960
# new_cases_smoothed                  928
# new_cases_smoothed_per_million      928
# total_deaths                        851
# total_deaths_per_million            851
# hospital_beds_per_thousand          742
# stringency_index                    635
# aged_70_older                       244
# human_development_index             241
# gdp_per_capita                      228
# aged_65_older                       212
# diabetes_prevalence                 173
# cardiovasc_death_rate               137
# population_density                  132
# median_age                           97
# new_cases                            81
# new_cases_per_million                81
# life_expectancy                      43
# total_cases_per_million               2
# total_cases                           2
# LOCDATE                               0
# INTER1                                0
# INTER2                                0
# SUB_EVENT_TYPE                        0
# EVENT_TYPE                            0
# population                            0
# COUNTRY                               0
# ISO                                   0
# REGION                                0
# iso_code                              0
# LATITUDE                              0
# LONGITUDE                             0
# SOURCE_SCALE                          0
# FATALITIES                            0
# DISORDER_TYPE                         0
# UNORGANIZED                           0
# date                                  0
# location                              0
# continent                             0
# EVENT_DATE                            0
# dtype: int64

# %% [markdown]
# Поскольку делать всё это еще несколько раз ручками мы не хотим, то
# ## Забацаем модуль

# %%
def dataclear(df,
             df_addition,
             useless_features = None,
             na_limit = 5
             ):
    """
    Предобработка ACLED датасета для анализа.

    Args:
        df(pd.DataFrame): Датафрейм с основными данными (ACLED).
        df_addition(pd.DataFrame): Датафрейм с дополнительными данными.
        useless_features(list): Список ненужных колонок.
        na_limit(int): Процент допустимых пропусков в колонках.
        
    Returns:
        pd.DataFrame: Обработанный датафрейм.
    """
    
    df.set_index("EVENT_ID_CNTY", inplace = True)
    df['EVENT_DATE'] = pd.to_datetime(df['EVENT_DATE'])
    df['ACTOR1_TYPES'] = df["ASSOC_ACTOR_1"].fillna(df["ACTOR1"])
    
    
    def process_string(row):
        new_string = row['ACTOR1_TYPES'].replace(' (' + row['COUNTRY'] + ')', '')
        return [new_string]
    df['ACTOR1_TYPES'] = df.apply(lambda row: pd.Series(process_string(row)), axis=1)
    df_actorcheck = df["ACTOR1_TYPES"].str.split(",", expand = True)
    
    my_list = ["Protesters", "Labor Group", "Health Workers", "Students", "Rioters", "Teachers", "Farmers", "Women", "Prisoners", "Taxi/Bus Drivers", "Lawyers", "Taxi Drivers", "No Vax", "Muslim Group", "Fishers", "Journalists", "Street Traders", "Orthodox Christian Group", "Protestant Christian Group", "Haredi Jewish Group", "Judges", "Refugees/IDPs", None]
    def check_list(row):
        return int(all(elem in my_list for elem in row))
    df['UNORGANIZED'] = df_actorcheck.apply(lambda row: check_list(row), axis=1)
    
    #работа со вторым датасетом
    df_addition['date'] = pd.to_datetime(df_addition['date'])
    df_addition["location"].replace(to_replace = "Czechia", value = "Czech Republic", inplace = True) #оправданный костыль
    
    #стыковка двух датасетов по общему столбцу
    df_addition["LOCDATE"] = df_addition["location"] + df_addition["date"].astype("str")
    df["LOCDATE"] = df["COUNTRY"] + df["EVENT_DATE"].astype("str")
    df_data = pd.merge(df, df_cov, on = "LOCDATE", how = "left")
    
    #очистка ненужных столбцов
    df_data = df_data.drop([
    'YEAR',
    'NOTES', #Текстовое описание новости
    'SOURCE', #Источник
    'TIME_PRECISION', #Точность определения времени события
    'TIMESTAMP', #Как оказалось, это время внесения наблюдения в таблицу
    'GEO_PRECISION', #Точность географической оценки
    'TAGS', #Плохо сделанные теги
    'ACTOR1', 
    'ASSOC_ACTOR_1', #Действующие лица
    'ACTOR2', 
    'ASSOC_ACTOR_2', 
    'CIVILIAN_TARGETING', #Было ли направленное именно на гражданские лица насилие
    'ADMIN1', 
    'ADMIN2',
    'ADMIN3', #Место действия
    'LOCATION',
    'INTERACTION',
    'ACTOR1_TYPES' #Служебная колонка
    ], axis = 1)
    if useless_features != None:
        df_data = df_data.drop(useless_features, axis = 1)
    df_data = df_data.drop(df_data[df_data["location"].isna()].index)
    df_data = df_data.drop(df_data.columns[df_data.isna().sum() > (na_limit * 0.01 * df_data.shape[0])], axis = 1)
    
    
    return(df_data)

# %% [markdown]
# Итак, на вход поступает два датафрейма и (опционально) список ненужных колонок и допустимый процент пропусков для колонки.Проверим, работает ли

# %%
df = pd.read_excel('datasets/coronavirus_Mar31.xlsx')
df_cov = pd.read_csv("datasets/owid-covid-data.csv")
dataclear(df, df_cov)
# Out:
#       EVENT_DATE       DISORDER_TYPE                  EVENT_TYPE  \
# 1     2020-03-19      Demonstrations                    Protests
# 2     2020-03-20      Demonstrations                    Protests
# 3     2020-03-21      Demonstrations                    Protests
# 4     2020-03-21      Demonstrations                    Protests
# 5     2020-03-21      Demonstrations                    Protests
# ...          ...                 ...                         ...
# 65711 2020-04-12  Political violence  Violence against civilians
# 65712 2020-07-24  Political violence  Violence against civilians
# 65713 2020-09-26  Political violence  Violence against civilians
# 65714 2020-10-08  Political violence                       Riots
# 65715 2021-03-01  Political violence                       Riots
#
#          SUB_EVENT_TYPE  INTER1  INTER2  ISO           REGION COUNTRY  \
# 1      Peaceful protest       6       0    0           Europe  Kosovo
# 2      Peaceful protest       6       0    0           Europe  Kosovo
# 3      Peaceful protest       6       0    0           Europe  Kosovo
# 4      Peaceful protest       6       0    0           Europe  Kosovo
# 5      Peaceful protest       6       0    0           Europe  Kosovo
# ...                 ...     ...     ...  ...              ...     ...
# 65711            Attack       1       7  894  Southern Africa  Zambia
# 65712            Attack       1       7  894  Southern Africa  Zambia
# 65713            Attack       1       7  894  Southern Africa  Zambia
# 65714      Mob violence       5       1  894  Southern Africa  Zambia
# 65715      Mob violence       5       7  894  Southern Africa  Zambia
#
#        LATITUDE  ...  median_age aged_65_older  aged_70_older  gdp_per_capita  \
# 1        42.667  ...         NaN           NaN            NaN        9795.834
# 2        42.667  ...         NaN           NaN            NaN        9795.834
# 3        42.667  ...         NaN           NaN            NaN        9795.834
# 4        42.659  ...         NaN           NaN            NaN        9795.834
# 5        42.638  ...         NaN           NaN            NaN        9795.834
# ...         ...  ...         ...           ...            ...             ...
# 65711   -13.700  ...        17.7          2.48          1.542        3689.251
# 65712   -14.243  ...        17.7          2.48          1.542        3689.251
# 65713   -15.417  ...        17.7          2.48          1.542        3689.251
# 65714   -15.417  ...        17.7          2.48          1.542        3689.251
# 65715   -13.550  ...        17.7          2.48          1.542        3689.251
#
#       cardiovasc_death_rate diabetes_prevalence female_smokers  \
# 1                       NaN                 NaN            NaN
# 2                       NaN                 NaN            NaN
# 3                       NaN                 NaN            NaN
# 4                       NaN                 NaN            NaN
# 5                       NaN                 NaN            NaN
# ...                     ...                 ...            ...
# 65711               234.499                3.94            3.1
# 65712               234.499                3.94            3.1
# 65713               234.499                3.94            3.1
# 65714               234.499                3.94            3.1
# 65715               234.499                3.94            3.1
#
#       hospital_beds_per_thousand life_expectancy  human_development_index
# 1                            NaN             NaN                      NaN
# 2                            NaN             NaN                      NaN
# 3                            NaN             NaN                      NaN
# 4                            NaN             NaN                      NaN
# 5                            NaN             NaN                      NaN
# ...                          ...             ...                      ...
# 65711                        2.0           63.89                    0.584
# 65712                        2.0           63.89                    0.584
# 65713                        2.0           63.89                    0.584
# 65714                        2.0           63.89                    0.584
# 65715                        2.0           63.89                    0.584
#
# [62723 rows x 45 columns]

# %% [markdown]
# Всё работает, результат идентичен ручной обработке, можно переходить к следующему этапу. Он в тетрадке 1.5 - Road to Visualisation.
