# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# # Подготовка визуализаций

# %%
df = pd.read_excel('datasets/disorders.xlsx')
df.set_index(df.columns[0], inplace = True)
df['EVENT_DATE'] = pd.to_datetime(df['EVENT_DATE'])
df.head()
# Out:
#            EVENT_DATE   DISORDER_TYPE EVENT_TYPE    SUB_EVENT_TYPE  INTER1  \
# Unnamed: 0
# 1          2020-03-19  Demonstrations   Protests  Peaceful protest       6
# 2          2020-03-20  Demonstrations   Protests  Peaceful protest       6
# 3          2020-03-21  Demonstrations   Protests  Peaceful protest       6
# 4          2020-03-21  Demonstrations   Protests  Peaceful protest       6
# 5          2020-03-21  Demonstrations   Protests  Peaceful protest       6
#
#             INTER2  ISO  REGION COUNTRY  LATITUDE  ...  median_age  \
# Unnamed: 0                                         ...
# 1                0    0  Europe  Kosovo    42.667  ...         NaN
# 2                0    0  Europe  Kosovo    42.667  ...         NaN
# 3                0    0  Europe  Kosovo    42.667  ...         NaN
# 4                0    0  Europe  Kosovo    42.659  ...         NaN
# 5                0    0  Europe  Kosovo    42.638  ...         NaN
#
#            aged_65_older  aged_70_older  gdp_per_capita cardiovasc_death_rate  \
# Unnamed: 0
# 1                    NaN            NaN        9795.834                   NaN
# 2                    NaN            NaN        9795.834                   NaN
# 3                    NaN            NaN        9795.834                   NaN
# 4                    NaN            NaN        9795.834                   NaN
# 5                    NaN            NaN        9795.834                   NaN
#
#            diabetes_prevalence female_smokers hospital_beds_per_thousand  \
# Unnamed: 0
# 1                          NaN            NaN                        NaN
# 2                          NaN            NaN                        NaN
# 3                          NaN            NaN                        NaN
# 4                          NaN            NaN                        NaN
# 5                          NaN            NaN                        NaN
#
#            life_expectancy  human_development_index
# Unnamed: 0
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# 5                      NaN                      NaN
#
# [5 rows x 45 columns]

# %% [markdown]
# Для географических визуализаций будем использовать библиотеку GeoPandas

# %%
shape = gpd.read_file("mapshape/ne_110m_admin_0_countries.shp") #файл с картой

# %%
df_sum = df[["UNORGANIZED", "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).sum()
df_sum["DISORDERS"] = df[["UNORGANIZED", "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).count()
df_sum["RATIO"] = df_sum["UNORGANIZED"] / df_sum["DISORDERS"]
df_sum.reset_index(inplace = True)
df_sum["ISO"].astype("int64")
df_sum
# Out:
#      ISO            COUNTRY  UNORGANIZED  DISORDERS     RATIO
# 0      0             Kosovo           37         43  0.860465
# 1      4        Afghanistan            8         36  0.222222
# 2      8            Albania           67         86  0.779070
# 3     12            Algeria          269        316  0.851266
# 4     20            Andorra            3          4  0.750000
# ..   ...                ...          ...        ...       ...
# 189  860         Uzbekistan           27         35  0.771429
# 190  862          Venezuela          759        850  0.892941
# 191  876  Wallis and Futuna            2          4  0.500000
# 192  887              Yemen           14         49  0.285714
# 193  894             Zambia            2          5  0.400000
#
# [194 rows x 5 columns]

# %% [markdown]
# Теперь у нас есть табличка, в которой наблюдения по странам просуммированы, и новый признак - соотношение "неорганизованных" событий ко всем.
# Соединим файл наблюдений с файлом карты.

# %%
df_geo = shape[["ISO_N3", "NAME", "geometry"]]
df_geo.loc[:, "ISO"] = pd.to_numeric(df_geo["ISO_N3"])  #Делаем столбец ISO одинаковым для обоих датасетов
df_geo = df_geo.drop(labels = "ISO_N3", axis = 1)
df_geo = df_geo.merge(df_sum, on="ISO")
df_geo
# Out:
# S:\Python\lib\site-packages\geopandas\geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                          NAME  \
# 0                        Fiji
# 1                    Tanzania
# 2                      Canada
# 3    United States of America
# 4                  Kazakhstan
# ..                        ...
# 155           North Macedonia
# 156                    Serbia
# 157                Montenegro
# 158       Trinidad and Tobago
# 159                  S. Sudan
#
#                                               geometry  ISO  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  242
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...  834
# 2    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...  124
# 3    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...  840
# 4    POLYGON ((87.35997 49.21498, 86.59878 48.54918...  398
# ..                                                 ...  ...
# 155  POLYGON ((22.38053 42.32026, 22.88137 41.99930...  807
# 156  POLYGON ((18.82982 45.90887, 18.82984 45.90888...  688
# 157  POLYGON ((20.07070 42.58863, 19.80161 42.50009...  499
# 158  POLYGON ((-61.68000 10.76000, -61.10500 10.890...  780
# 159  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...  728
#
#                  COUNTRY  UNORGANIZED  DISORDERS     RATIO
# 0                   Fiji            6          7  0.857143
# 1               Tanzania            1          2  0.500000
# 2                 Canada          626        730  0.857534
# 3          United States         5214       7736  0.673992
# 4             Kazakhstan          247        266  0.928571
# ..                   ...          ...        ...       ...
# 155      North Macedonia           60         77  0.779221
# 156               Serbia          128        147  0.870748
# 157           Montenegro           42         44  0.954545
# 158  Trinidad and Tobago           22         40  0.550000
# 159          South Sudan            2          6  0.333333
#
# [160 rows x 7 columns]

# %% [markdown]
# Нарисуем пробную карту

# %%
fig, ax = plt.subplots()
shape.plot(color="red", ax = ax)
df_geo.plot(column = "RATIO", legend = True, ax = ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Даже на этой маленькой карте видно, что на нашей карте, как минимум, нет Франции и Норвегии. А чего еще нет?

# %%
df_geo = shape[["ISO_N3", "geometry", "NAME", "ADMIN"]]
df_geo.loc[:, "ISO"] = pd.to_numeric(df_geo["ISO_N3"]) #Делаем столбец ISO одинаковым для обоих датасетов
df_geo = df_geo.drop(labels = "ISO_N3", axis = 1)
for iso in list(set(df_geo["ISO"]) - set(df_sum["ISO"])):
    print(df_geo[df_geo["ISO"] == iso][["ISO", "NAME"]])
# Out:
#     ISO           NAME
# 60  384  Côte d'Ivoire
#     ISO     NAME
# 89  548  Vanuatu
#     ISO                    NAME
# 23  260  Fr. S. Antarctic Lands
#      ISO        NAME
# 159   10  Antarctica
#     ISO      NAME
# 73  748  eSwatini
#     ISO       NAME
# 22  304  Greenland
#     ISO   NAME
# 67  178  Congo
#     ISO         NAME
# 24  626  Timor-Leste
#     ISO         NAME
# 45  630  Puerto Rico
#     ISO         NAME
# 95  408  North Korea
#      ISO          NAME
# 106  795  Turkmenistan
#    ISO       NAME
# 2  732  W. Sahara
#      ISO        NAME
# 21   -99      Norway
# 43   -99      France
# 160  -99   N. Cyprus
# 167  -99  Somaliland
# 174  -99      Kosovo

# %% [markdown]
# Много где не совпало, и хоть бОльшая часть территорий - это какие - то сомнительные острова без наблюдений, попытаемся соединить всё

# %%
df_geo = shape[["ISO_N3", "geometry", "NAME", "ADMIN"]]
df_geo.loc[:, "ISO"] = pd.to_numeric(df_geo["ISO_N3"]) #Делаем столбец ISO одинаковым для обоих датасетов
df_geo = df_geo.drop(labels = "ISO_N3", axis = 1)

#стыковка ISO
join_dict = df_sum.set_index("COUNTRY")["ISO"].to_dict()
iso_unstacked = list(set(df_geo["ISO"]) - set(df_sum["ISO"]))

for iso in iso_unstacked:
    mask = df_geo["ISO"] == iso
    df_geo.loc[mask, "ISO"] = df_geo.loc[mask, "NAME"].map(join_dict).values
# Out:
# S:\Python\lib\site-packages\geopandas\geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
df_geo.isna().sum()
# Out:
# geometry     0
# NAME         0
# ADMIN        0
# ISO         14
# dtype: int64

# %% [markdown]
# Потеряли 14 стран, но по ним не было наблюдений. <br>Соединим снова

# %%
df_geo = df_geo.merge(df_sum, on="ISO")
df_geo
# Out:
#                                               geometry  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# 4    POLYGON ((87.35997 49.21498, 86.59878 48.54918...
# ..                                                 ...
# 158  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 159  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 160  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 161  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 162  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#                          NAME                        ADMIN    ISO  \
# 0                        Fiji                         Fiji  242.0
# 1                    Tanzania  United Republic of Tanzania  834.0
# 2                      Canada                       Canada  124.0
# 3    United States of America     United States of America  840.0
# 4                  Kazakhstan                   Kazakhstan  398.0
# ..                        ...                          ...    ...
# 158                    Serbia           Republic of Serbia  688.0
# 159                Montenegro                   Montenegro  499.0
# 160                    Kosovo                       Kosovo    0.0
# 161       Trinidad and Tobago          Trinidad and Tobago  780.0
# 162                  S. Sudan                  South Sudan  728.0
#
#                  COUNTRY  UNORGANIZED  DISORDERS     RATIO
# 0                   Fiji            6          7  0.857143
# 1               Tanzania            1          2  0.500000
# 2                 Canada          626        730  0.857534
# 3          United States         5214       7736  0.673992
# 4             Kazakhstan          247        266  0.928571
# ..                   ...          ...        ...       ...
# 158               Serbia          128        147  0.870748
# 159           Montenegro           42         44  0.954545
# 160               Kosovo           37         43  0.860465
# 161  Trinidad and Tobago           22         40  0.550000
# 162          South Sudan            2          6  0.333333
#
# [163 rows x 8 columns]

# %% [markdown]
# Посмотрим на карту снова

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo.plot(column = "DISORDERS", legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Тут видим, что напрямую от количества населения в стране количество событий не зависит - сильнее всех "светится" США, а вот Китай и Африка, например, совсем темная. Нужно корректировать количество наблюдений при помощи индекса свободы прессы и социоэкономики, например.

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo.plot(column = "RATIO", legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Сложно что-то сказать по этой карте, кроме того, что есть страны с аномально "Организованными простестами"

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(color="lightgrey", ax=ax)
plt.scatter(x = df[df["UNORGANIZED"] == 1]['LONGITUDE'], y = df[df["UNORGANIZED"] == 1]['LATITUDE'], alpha=1, cmap='autumn', s = 0.3)
plt.scatter(x = df[df["UNORGANIZED"] == 0]['LONGITUDE'], y = df[df["UNORGANIZED"] == 0]['LATITUDE'], alpha=0.3, cmap='autumn', s = 0.3)

# %% [markdown]
# Очевидная новость - события распределены преимущественно вдоль побережий, где в основном и находятся населенные пункты (Можно выдвинуть гипотезу и проверить корреляцию количества событий с плотностью населения).
#
# Повторим все карты для датасета с протестами.

# %%
def geo_join(dataset_name_excel, mapshape_file):
    
    
    df = pd.read_excel(dataset_name_excel) #датасет
    df.set_index(df.columns[0], inplace = True)
    df['EVENT_DATE'] = pd.to_datetime(df['EVENT_DATE'])
    
    df_sum = df[["UNORGANIZED", "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).sum()
    df_sum["DISORDERS"] = df[["UNORGANIZED", "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).count()
    df_sum["RATIO"] = df_sum["UNORGANIZED"] / df_sum["DISORDERS"]
    df_sum.reset_index(inplace = True)
    df_sum["ISO"].astype("int64")    
    
    shape = gpd.read_file(mapshape_file) #файл карты
    df_geo = shape[["ISO_N3", "geometry", "NAME"]]
    df_geo.loc[:, "ISO"] = pd.to_numeric(df_geo["ISO_N3"]) #Делаем столбец ISO одинаковым для обоих датасетов
    df_geo = df_geo.drop(labels = "ISO_N3", axis = 1)
    
    #стыковка ISO
    join_dict = df_sum.set_index("COUNTRY")["ISO"].to_dict()
    iso_unstacked = list(set(df_geo["ISO"]) - set(df_sum["ISO"]))

    for iso in iso_unstacked:
        mask = df_geo["ISO"] == iso
        df_geo.loc[mask, "ISO"] = df_geo.loc[mask, "NAME"].map(join_dict).values
        
    df_geo = df_geo.merge(df_sum, on="ISO")
    return df_geo

# %%
df_geo2 = geo_join("datasets/disorders.xlsx","mapshape/ne_110m_admin_0_countries.shp")
# Out:
# S:\Python\lib\site-packages\geopandas\geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo2.plot(column = "DISORDERS", legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo2.plot(column = "RATIO", legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# В целом картина изменилась не сильно, так как протесты составляют...

# %%
len(df2["ISO"].tolist()) / len(df["ISO"].tolist())
# Out:
# 0.9378842291070668

# %% [markdown]
# Сделаю огромную жуткую функцию, в которую можно будет подавать два датасета (с данными и с географией) и кучу списков параметров, которая будет сама делать датасет для визуализации.

# %%
def geo_join_pro(dataset_name_excel, mapshape_file,
                 dataset_target, #
                 dataset_features_cum, #Кумулятивные признаки ("Всего заболело")
                 dataset_features_stat, #Статистические признаки ("ВВП на душу населения")
                 dataset_features_dyn, #Признаки наблюдений ("UNORGANIZED", "FATALITIES")
                 dataset_features_dyn_ratio #Тоже признаки наблюдений, но для расчета долей
                ):
    
    df = pd.read_excel(dataset_name_excel) #датасет
    df.set_index(df.columns[0], inplace = True)
    df['EVENT_DATE'] = pd.to_datetime(df['EVENT_DATE'])
    
    df_sum = df[[dataset_target, "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).sum()
    
    for feature in dataset_features_cum:
        df_sum[feature] = df[[feature, "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).last().fillna(method="ffill")
        
    for feature in dataset_features_stat:
        df_sum[feature] = df[[feature, "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).mean()
    
    for feature in dataset_features_dyn:
        df_sum[feature] = df[[feature, "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).sum()
    
    for feature in dataset_features_dyn_ratio:
        df_sum[feature + "_RATIO"] = df[[feature, "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).sum() / df[[feature, "ISO", "COUNTRY"]].groupby(by = ["ISO", "COUNTRY"]).count()
    
    df_sum.reset_index(inplace = True)
    df_sum["ISO"].astype("int64")    
    
    shape = gpd.read_file(mapshape_file) #файл карты
    df_geo = shape[["ISO_N3", "geometry", "NAME"]]
    df_geo.loc[:, "ISO"] = pd.to_numeric(df_geo["ISO_N3"]) #Делаем столбец ISO одинаковым для обоих датасетов
    df_geo = df_geo.drop(labels = "ISO_N3", axis = 1)
    
    #стыковка ISO
    join_dict = df_sum.set_index("COUNTRY")["ISO"].to_dict()
    iso_unstacked = list(set(df_geo["ISO"]) - set(df_sum["ISO"]))

    for iso in iso_unstacked:
        mask = df_geo["ISO"] == iso
        df_geo.loc[mask, "ISO"] = df_geo.loc[mask, "NAME"].map(join_dict).values
        
    df_geo = df_geo.merge(df_sum, on="ISO")
    return df_geo

# %%
dset = "datasets/disorders.xlsx"
mapfile = "mapshape/ne_110m_admin_0_countries.shp"
target = "UNORGANIZED"
ds_cum = ["total_cases", 'total_cases_per_million', "total_deaths", 'total_deaths_per_million']
ds_stat = ['reproduction_rate',
       'stringency_index', 'population', 'population_density', 'median_age',
       'aged_65_older', 'aged_70_older', 'gdp_per_capita',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'hospital_beds_per_thousand', 'life_expectancy',
       'human_development_index']
ds_dyn = ['FATALITIES']
ds_dyn_ratio = ['UNORGANIZED', 'FATALITIES']

df_geo = geo_join_pro(dset, mapfile, target, ds_cum, ds_stat, ds_dyn, ds_dyn_ratio)
df_geo
# Out:
# S:\Python\lib\site-packages\geopandas\geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                                               geometry  \
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# 4    POLYGON ((87.35997 49.21498, 86.59878 48.54918...
# ..                                                 ...
# 158  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 159  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 160  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 161  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 162  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#                          NAME    ISO              COUNTRY  UNORGANIZED  \
# 0                        Fiji  242.0                 Fiji            6
# 1                    Tanzania  834.0             Tanzania            1
# 2                      Canada  124.0               Canada          626
# 3    United States of America  840.0        United States         5214
# 4                  Kazakhstan  398.0           Kazakhstan          247
# ..                        ...    ...                  ...          ...
# 158                    Serbia  688.0               Serbia          128
# 159                Montenegro  499.0           Montenegro           42
# 160                    Kosovo    0.0               Kosovo           37
# 161       Trinidad and Tobago  780.0  Trinidad and Tobago           22
# 162                  S. Sudan  728.0          South Sudan            2
#
#      total_cases  total_cases_per_million  total_deaths  \
# 0        52532.0                58181.480         697.0
# 1          480.0                    7.805          16.0
# 2      3334009.0                87580.556       36998.0
# 3     79265726.0               238095.936      958437.0
# 4      1389288.0                73139.830       18906.0
# ..           ...                      ...           ...
# 158    1913861.0               278519.670       15280.0
# 159     223774.0               356299.090        2610.0
# 160     161227.0                90469.470        2988.0
# 161     126502.0                90141.331        3608.0
# 162      10381.0                  912.104         114.0
#
#      total_deaths_per_million  reproduction_rate  ...  gdp_per_capita  \
# 0                     771.958           1.512857  ...        8702.975
# 1                       0.260           0.240000  ...        2683.304
# 2                     971.895           0.955831  ...       44017.591
# 3                    2878.923           1.043706  ...       54225.446
# 4                     995.317           1.118893  ...       24055.588
# ..                        ...                ...  ...             ...
# 158                  2223.662           1.127075  ...       14048.881
# 159                  4155.713           1.096818  ...       16409.288
# 160                  1676.659           0.925278  ...        9795.834
# 161                  2570.947           0.990278  ...       28763.071
# 162                    10.016           0.690000  ...        1569.888
#
#      cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                  412.820                14.49            10.2
# 1                  217.288                 5.75             3.3
# 2                  105.599                 7.37            12.0
# 3                  151.089                10.79            19.1
# 4                  466.792                 7.11             7.0
# ..                     ...                  ...             ...
# 158                439.415                10.08            37.7
# 159                387.305                10.08            44.0
# 160                    NaN                  NaN             NaN
# 161                228.467                10.97             NaN
# 162                280.775                10.43             NaN
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         2.300            67.44                    0.743
# 1                         0.700            65.46                    0.529
# 2                         2.500            82.43                    0.929
# 3                         2.770            78.86                    0.926
# 4                         6.700            73.60                    0.825
# ..                          ...              ...                      ...
# 158                       5.609            76.00                    0.806
# 159                       3.861            76.88                    0.829
# 160                         NaN              NaN                      NaN
# 161                       3.000            73.51                    0.796
# 162                         NaN            57.85                    0.433
#
#      FATALITIES  UNORGANIZEDRATIO  FATALITIESRATIO
# 0             0          0.857143         0.000000
# 1             0          0.500000         0.000000
# 2             0          0.857534         0.000000
# 3             5          0.673992         0.000646
# 4             0          0.928571         0.000000
# ..          ...               ...              ...
# 158           0          0.870748         0.000000
# 159           0          0.954545         0.000000
# 160           0          0.860465         0.000000
# 161           0          0.550000         0.000000
# 162           0          0.333333         0.000000
#
# [163 rows x 26 columns]

# %%
df_geo.columns
# Out:
# Index(['geometry', 'NAME', 'ISO', 'COUNTRY', 'UNORGANIZED', 'total_cases',
#        'total_cases_per_million', 'total_deaths', 'total_deaths_per_million',
#        'reproduction_rate', 'stringency_index', 'population',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'cardiovasc_death_rate', 'diabetes_prevalence',
#        'female_smokers', 'hospital_beds_per_thousand', 'life_expectancy',
#        'human_development_index', 'FATALITIES', 'UNORGANIZEDRATIO',
#        'FATALITIESRATIO'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo.plot(column = "FATALITIESRATIO", legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo.plot(column = "FATALITIES", legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo.plot(column = 'total_deaths', legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo.plot(column = 'UNORGANIZEDRATIO', legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20, 16))
shape.plot(ax=ax, color="lightgrey")
df_geo.plot(column = 'total_cases', legend = True, legend_kwds={'shrink': 0.3}, ax=ax)
# Out:
# <AxesSubplot:>

# %%
df_geo.corr()["UNORGANIZEDRATIO"]
# Out:
# ISO                          -0.099518
# UNORGANIZED                   0.136842
# total_cases                   0.051519
# total_cases_per_million       0.269370
# total_deaths                  0.100876
# total_deaths_per_million      0.325019
# reproduction_rate            -0.028853
# stringency_index             -0.097291
# population                   -0.057182
# population_density           -0.091061
# median_age                    0.224904
# aged_65_older                 0.295147
# aged_70_older                 0.285609
# gdp_per_capita               -0.088016
# cardiovasc_death_rate        -0.001396
# diabetes_prevalence          -0.086448
# female_smokers                0.268974
# hospital_beds_per_thousand    0.137953
# life_expectancy               0.153367
# human_development_index       0.164583
# FATALITIES                   -0.070540
# UNORGANIZEDRATIO              1.000000
# FATALITIESRATIO              -0.210176
# Name: UNORGANIZEDRATIO, dtype: float64

# %%
df_geo.corr()["UNORGANIZEDRATIO"]
